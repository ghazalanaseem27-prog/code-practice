# %% [markdown]
# <a href="https://colab.research.google.com/github/ghazalanaseem27-prog/practice-python-code/blob/main/oop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OOP
# ### class
# ### object

# %%
# to understand oop we need to understand class and object

#in class we write data and function
# python have two type of class-> built-in-function, user defined function
 #object is an instance of class

# %%
#syantax to create an class

l=[1,2,3,4,5]
print(type(l))

# %%
# syntax to understand object

# objectname = classname

l=[1,2,3,4,5]

# we ca create list also this

l=list()
l

# %%
# program

class Atm:

  # constructor

  def __init__(self):
    self.pin=''
    self.balance= 8000
    print('now i am executed')
    self.menu()

  def menu(self):
   user_input=input("""
   Hi how can I help you?
   1. Press 1 for enter pin.
   2. press 2 for change pin.
   3. press 3 for check balance.
   4. press 5 for withdraw.
   5. press 4 for deposit.
  """)
   if user_input=='1':
    self.enter_pin()
   elif user_input=='2':
    self.change_pin()
   elif user_input=='3':
    self.check_balance()
   elif user_input=='4':
    self.withdraw()
   else :
    self.deposit()

  def enter_pin(self):
   user_pin = input('enter your pin')
   self.pin=user_pin
   print('pin set successfully')
   self.menu()
   user_balance=('enter balance')
   self.balance = user_balance
   print('enter successfully')

   self.menu()

  def change_pin(self):
    old_pin=input('enter your old pin')
    if old_pin==self.pin:
      new_pin=input('enter your new pin')
      self.pin=new_pin

      print('pin change successfully')

      self.menu()
    else:
      print('old pin is incorrect')
    self.menu()

  def check_balance(self):
    user_pin=input('enter your pin')
    if user_pin==self.pin:
      print('your balance is',self.balance)
    else:
      print('incorrect pin')
    self.menu()

  def withdraw(self):
    user_pin=input('enter your pin')
    if user_pin==self.pin:
      amount=int(input('enter the amount'))
      if amount<=self.balance:
        self_balance=self.balance-amount
        print('withdraw successfully.balance is',self_balance)
      else:
        print('insufficient balance')
    else:
      print('incorrect pin')
    self.menu()



obj = Atm()

print(type(obj))

# %% [markdown]
# # Method Vs Function
# ## Method-> if function is implemntend in a class so we called it metnod.
# ## Function-> if function is existing independentely out side of class so we called it function.

# %%
l=[1,2,3,4]
len(l) # len is function bcos it  is outeside the list class
l.append() # append is method bcos it is inside rhe list class

# %% [markdown]
# # What is constructor?
# ### constructor-> magic method,->special method->called --init--
#
# ### it runs automatically when create an object like -> obj=Atm() , main job -> set up initial data
#
# # Imtortance
#
# ### reduce repetative code, making program clean, well organized, easier to read
#
# ### you can trigger essentional function  immediately when program start like self.menu()
#
# ### you don't need to set up variable manually for new object

# %%
class fraction:

  def __init__(self,x,y):
    self.num=x
    self.den=y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num=self.num*other.den+other.num*self.den
    new_den=self.den*other.den
    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other):
    new_num=self.num*other.den-other.num*self.den
    new_den=self.den*other.den
    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num=self.num*other.num
    new_den=self.den*other.den
    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num=self.num*other.den
    new_den=self.den*other.num
    return '{}/{}'.format(new_num,new_den)

fr1 = fraction(2,3)
fr2 = fraction(3,4)

print(fr1)
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
