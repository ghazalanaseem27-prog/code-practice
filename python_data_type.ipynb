# %% [markdown]
# <a href="https://colab.research.google.com/github/ghazalanaseem27-prog/practice-python-code/blob/main/python_data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python output

# %%
# python is case senstive

print('Pakistan')
print(123)

print('hello world',1,2,3,sep='-')

print('hello',end='\t')
print('world')

print('hello','world',sep='\n')
# Out:
# Pakistan
# 123
# hello world-1-2-3
# hello	world
# hello
# world

# %% [markdown]
# # Data Type

# %%
# integer

print(829)
# Out:
# 829

# %%
# float

print(23.2)
print(23.0)
print(23.00)
# Out:
# 23.2
# 23.0
# 23.0

# %%
# string

print('hello world')
print("hello world")
print('''hello world''')
# Out:
# hello world
# hello world
# hello world

# %%
# boolean

print(True)
print(False)
# Out:
# True
# False

# %%
# complex num

print(2+3j)
# Out:
# (2+3j)

# %%
# list

print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tuple

print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# sets

print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
IMP # dictionary

print({'name':'ali','age':23})
# Out:
# {'name': 'ali', 'age': 23}

# %%
# none

print(None)
# Out:
# None

# %%
# type

print(type(23))
print(type(23.0))
print(type('hi'))
print(type(True))
print(type(2+3j))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %% [markdown]
# # Variables

# %%
# Statics Vs Dynamic typing
# statics Vs Dynamic binding
# stylish declaration techniques

# %%
# dynamic binding
# we don't have any fixed data type
# we can use any type or data in a program

a=5
print(a)
a='Ghazala'
print(a)

# static binding
# if we use a variable we can't change its data type in a program

int a =5
print(a)
# Out:
# 5
# Ghazala

# %%
a=1
b=4
c=5
print(a,b,c)
# Out:
# 1 4 5

# %%
a,b,c=6,7,3
print(a,b,c)
# Out:
# 6 7 3

# %%
a=b=3
print(a,b)
# Out:
# 3 3

# %% [markdown]
# # Comments
# ### . if want any thing for understanding code to other so, we can write comments

# %%
# this is comment

# %% [markdown]
# # Keywords & Identifiers

# %% [markdown]
# ### .  keyword/Interpreter are used to convert high level language in machine language line by line
#
# ### . Compiler also used for covert convert whole program in machine language

# %%
# Identifers   if we create own funtion,variable and cell this called identifier

# we can't start with digit like
#1name='Ghazala'
# but this is correct
name1='Ghazala'
# we can use special character
#first-name="Ghazala"
# we can use under score
_="Ghazala"
print(_)
# identifier can't be keyword
# Out:
# Ghazala

# %% [markdown]
# # User input

# %%
input('enter name :')
# Out:
# enter name :Ghazala
# 'Ghazala'

# %%
# Program

fstnum = int(input('enter 1st number :'))
secnum = int(input('enter 2nd number :'))
print(fstnum+secnum)
# Out:
# enter 1st number :64
# enter 2nd number :38
# 102

# %% [markdown]
# # Type conversion

# %%
# implicit type conversion
# python convert datatype by its own

print(5+5.6)
print(type(5),type(5.6))
# explicit type conversion
# we asked for change data type

print(5.6+9)
print(type(float(9)))
# Out:
# 10.6
# <class 'int'> <class 'float'>
# 14.6
# <class 'float'>

# %% [markdown]
# # Literal

# %%
# the value we give to variable is called literal

a=2

# %%
a=True+4
print(a)
b=False+2
print(b)
# Out:
# 5
# 2

# %%
# for future use
x=None
a=3
print(x,a)
# Out:
# None 3
